# %%
def printme(str):
    #This is a print function
    print (str)
    return

printme("I'm first call to user defined function!")
printme("Again second call to the same function")
# Out:
# I'm first call to user defined function!
# Again second call to the same function

# %%
def changeme( mylist ):
    #This changed a passed list
    mylist.append([1,2,3,4])
    print("values inside the function: ", mylist)
    return
mylist = [10,20,30]
changeme( mylist )
print ("Values outside the function: ", mylist)
# Out:
# values inside the function:  [10, 20, 30, [1, 2, 3, 4]]
# Values outside the function:  [10, 20, 30, [1, 2, 3, 4]]

# %%
def changeme( mylist ):
    #This changes a passed list
    mylist = [1,2,3,4];
    print("Values inside the function: ", mylist)
mylist = [10,20,30];
changeme( mylist );
print ("Values outside the fuction: ", mylist)
# Out:
# Values inside the function:  [1, 2, 3, 4]
# Values outside the fuction:  [10, 20, 30]

# %%
def printme( str ):
    #This prints a passed string
    print (str);
    return
printme(str)
# Out:
# <class 'str'>

# %%
def printme(text):
    # This prints a passed string
    # Changed parameter name from 'str' to 'text' to avoid conflict with built-in str() function
    print(text)
    return

printme(text = "My string")
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[16], line 7
#       4     print(text)
#       5     return
# ----> 7 printme(text = "My string")
#
# Cell In[16], line 4, in printme(text)
#       1 def printme(text):
#       2     # This prints a passed string
#       3     # Changed parameter name from 'str' to 'text' to avoid conflict with built-in str() function
# ----> 4     print(text)
#       5     return
#
# Cell In[10], line 3, in print(str)
#       1 def print( str ):
#       2     #This prints a passed string
# ----> 3     print (str);
#       4     return
#
# Cell In[10], line 3, in print(str)
#       1 def print( str ):
#       2     #This prints a passed string
# ----> 3     print (str);
#       4     return
#
#     [... skipping similar frames: print at line 3 (2973 times)]
#
# Cell In[10], line 3, in print(str)
#       1 def print( str ):
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[15], line 5
#       3     print (str);
#       4     return
# ----> 5 printme( str = "My string")
#
# Cell In[15], line 3, in printme(str)
#       1 def printme( str ):
#       2     #This prints a passed string
# ----> 3     print (str);
#       4     return
#
# Cell In[10], line 3, in print(str)
#       1 def print( str ):
#       2     #This prints a passed string
# ----> 3     print (str);
#       4     return
#
# Cell In[10], line 3, in print(str)
#       1 def print( str ):
#       2     #This prints a passed string
# ----> 3     print (str);
#       4     return
#
#     [... skipping similar frames: print at line 3 (2973 times)]
#
# Cell In[10], line 3, in print(str)
#       1 def print( str ):
#       2     #This prints a passed string
# ----> 3     print (str);
#       4     return
#
# ...

# %%
def printinfo( name, age ):
    #Test function
    print("Name: ", name)
    print("Age: ",age)
    return
printinfo = input("Age: ")
printinfo = input("Name: ")
# Out:
# Age:  16
# Name:  femi

# %%
def printinfo(name, age = 35):
    #Test function
    print("Name: ", name)  # Changed to use comma as separator between arguments
    print("Age: ", age)    # Changed to use comma as separator between arguments
    return

printinfo(name="miki", age=50)
printinfo(name="miki")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 7
#       4     print("Age: ", age)    # Changed to use comma as separator between arguments
#       5     return
# ----> 7 printinfo(name="miki", age=50)
#       8 printinfo(name="miki")
#
# Cell In[25], line 3, in printinfo(name, age)
#       1 def printinfo(name, age = 35):
#       2     #Test function
# ----> 3     print("Name: ", name)  # Changed to use comma as separator between arguments
#       4     print("Age: ", age)    # Changed to use comma as separator between arguments
#       5     return
#
# TypeError: print() takes 1 positional argument but 2 were given

# %%
total = 50; #This is a global variable
def sum( arg1, arg2 ):
    # Add both the parameters
    total = arg1 + arg2;
    print ("Inside the function local total : ",total)
    return total;
# Now you can call sum function
sum(10,20 )
print("Outside the function global total : ",total)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 8
#       6     return total;
#       7 # Now you can call sum function
# ----> 8 sum(10,20 )
#       9 print("Outside the function global total : ",total)
#
# Cell In[30], line 5, in sum(arg1, arg2)
#       2 def sum( arg1, arg2 ):
#       3     # Add both the parameters
#       4     total = arg1 + arg2;
# ----> 5     print ("Inside the function local total : ",total)
#       6     return total
#
# TypeError: print() takes 1 positional argument but 2 were given

# %%
def swap(x, y):
    global a
    a = "Lawal"
    x, y = y, x
    b = "Chris"
    b = "Edward"
    c = "Lola"
    print(a, b, x, y)
    a = "Mary"

swap("Tina", "Tolu")
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 11
#       8     print(a, b, x, y)
#       9     a = "Mary"
# ---> 11 swap("Tina", "Tolu")
#      12 print(a)
#
# Cell In[31], line 8, in swap(x, y)
#       6 b = "Edward"
#       7 c = "Lola"
# ----> 8 print(a, b, x, y)
#       9 a = "Mary"
#
# TypeError: print() takes 1 positional argument but 4 were given
